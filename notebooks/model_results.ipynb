# %% [markdown]
# ## Model Comparison Results
#
# | **Model**    | **Time Taken (seconds)** | **Memory Used (MB)** | **Summary Quality**                              |
# |--------------|--------------------------|----------------------|--------------------------------------------------|
# | **BART (M1)**   | 8.53                     | 0.2484                | Well-structured, detailed, and preserves key insights |
# | **T5 (M2)**     | 3.21                     | 0.2126                | Fast, but occasionally lacks coherence           |
# | **PEGASUS (M3)**| 12.53                    | 0.0724               | Extremely concise, but loses important details   |
#
# ---
#
# ### Final Verdict
#
# **Best for Balanced Summarization (Detail + Clarity): BART (M1)**
# - Provides well-structured summaries with good readability and retention of key details.
# - Slightly slower than T5 but offers the most comprehensive summary among the three.
#
# **Best for Speed & Efficiency: T5 (M2)**
# - The fastest model, completing the task in 3.31 seconds.
# - Uses moderate memory but sometimes sacrifices key details in the summary.
#
# **Best for Extreme Compression & Minimal Memory Use: PEGASUS (M3)**
# - Uses the least memory (0.0731 MB) but takes the longest time (12.83 sec).
# - The summary is highly compressed, which may be useful for short snippets but risks omitting crucial information.
#
# ---
#
# ### Conclusion
# - If the goal is **accuracy and completeness**, **BART (M1)** is the best choice despite being slower.
# - If **speed** is the priority, **T5 (M2)** performs best, though it may miss some nuances.
# - If **memory efficiency** and extreme brevity are required, **PEGASUS (M3)** is effective but not ideal for in-depth summarization.
#
# For most **general-purpose summarization tasks**, where **clarity, completeness, and readability** matter, **BART (M1)** emerges as the best model in this study.
